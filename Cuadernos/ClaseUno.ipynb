# %% [markdown]
# # Clase # 1.

# %% [markdown]
# ##### *¿Qué aprendí la primera clase?*

# %%
# La respuesta siempre será DEPENDE
Concatenar = "1"+ "1"
Sumar = 1+1

print(Concatenar)
print(Sumar)
# Out:
# 11
# 2

# %% [markdown]
# ##### **Conceptos clave.**
# - Machine learning: Un campo de la ciencia informatica que aprende automaticamente luego de unos datos especificos. Se encarga de generar comportamientos diferentes con esos datos.
# - Notebook
# - Tensor flow: Código abierto, desarrollado por google. Detecta y decifra patrones.
# - Test de turing: Es una prueba para medir la inteligencia de la computadora y el ser humano.
# - Hacking

# %% [markdown]
# ###### **Personaje de interés**
#
# *Elon Musk*
#
# <img src="data:image/jpeg;base64,..." width="140" height="240" align="center"/>
#
# *Creador de tesla motors, presidente de SolarCity, cofundador de Paypal, inventor, emprendedor y físico.*
#
#
# Cofundador de [OpenAi](https://openai.com/), empresa de inteligencia artificial, la cual tiene un video de escondidas donde se ve como la misma maquina detecta cosas que al desarrollador se le escapan. [Mira el video aquí](https://openai.com/blog/emergent-tool-use/)

# %% [markdown]
# ##### **Series y peliculas que se debenver.**
# - Código enigma
# - Mr. Robot
# - El Resplandor
