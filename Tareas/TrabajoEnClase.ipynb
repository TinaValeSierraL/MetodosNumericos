# %%
len("Valentina")
# Out:
# 9

# %%
numero = len("valentina")
print(numero)
# Out:
# 9

# %%
x = len("Valentina maria")
if x>10:
    print("I'm ready to code");
else:
        print("Hello")
# Out:
# I'm ready to code
